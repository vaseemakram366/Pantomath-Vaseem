# %% [markdown]
# <a href="https://colab.research.google.com/github/vaseemakram366/Pantomath-Vaseem/blob/main/AIML_Batch_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=29
y=34
x+y
# Out:
# 63

# %%
a=34
b=34
a=a+b
print(a)
# Out:
# 68

# %%
c=100
c=300
print(c)
# Out:
# 300

# %%
sfdf = 23
print(sfdf)
# Out:
# 23
