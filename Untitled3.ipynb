# %% [markdown]
# <a href="https://colab.research.google.com/github/vaseemakram366/Pantomath-Vaseem/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("i am vaseem akram hey")
# Out:
# i am vaseem akram hey

# %%
name = "vaseem"
print(name)
# Out:
# vaseem

# %% [markdown]
# Hello I am Vaseem Akram . I am a web developer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
